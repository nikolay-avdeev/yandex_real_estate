# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Николай :)
#
# Спасибо за работу на проекте
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />    Привет, Николай :) Спасибо за все исправления и комментарии
#
# Критические ❌ комментарии остались:
#
#
# + настроить фильтрацию редких значений в п. 2.4, учесть пропуски
# + перепроверить итоговый вывод после восстановления данных
#
# добавил подсказок и бонус
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Николай :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться).
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит делить блок загрузки библиотек и код загрузки датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %% [markdown]
# <font color='blue'>Поправил. Спасибо за рекомендацию, не думал об этом.</font>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Убрать служ. информацию поможет точка с запятой на посл. строке кода
#
#     array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
#
# data.hist(figsize=(15, 20));

# %% [markdown]
# <font color='blue'>Не знал, спасибо!</font>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> обзор данных проведен корректно

# %% [markdown]
# ### Предобработка данных

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind= 'barh', figsize=(19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста

# %% [markdown]
# <font color='blue'>Спасибо за пример 😍</font>

# %% [markdown]
# <font color='blue'>В документации к таблице я обнаружил что столбец 'is_apartment' должен иметь тип bool, по факту столбец имеет тип object и много пропущенных значений. Сделав фильтрацию про строкам содержащим пропущенные значения я чего-то необычного не обнаружил и предпологаю что у владельца данных о том что квартира является аппартаментами нет и пропущенные значения это False. Делаю замену Nan на False.</font>

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %% [markdown]
# <font color='blue'>По такому же принципу в столбце 'balcony' предполагаю что значение NaN означает что балконов нет, заменим эти значения на 0</font>

# %%
data['balcony'] = data['balcony'].fillna(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <font color='blue'>Посмотрим уникальные значения столбца 'locality_name'</font>

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
len(data['locality_name'].unique())
# Out:
# 365

# %% [markdown]
# <font color='blue'>Заменим букву 'ё' на 'е', 'поселок городского типа' на 'городской поселок', 'поселок при железнодорожной станции' на 'поселок станции'. Строки с пропущенными значениями удалим. В результате получаем 321 уникальных значения.</font>

# %%
data['locality_name'] = data['locality_name'].str.replace('ё', 'е')
data['locality_name'] = data['locality_name'].str.replace('поселок городского типа', 'городской поселок')
data['locality_name'] = data['locality_name'].str.replace('поселок при железнодорожной станции', 'поселок станции')
#data['locality_name'] = data['locality_name'].fillna('нет данных')
data = data[~data['locality_name'].isnull()]

# %%
len(data['locality_name'].unique())
# Out:
# 321

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />хорошая работа по избавлению от неявных дубликатов

# %% [markdown]
# #### Потолки

# %% [markdown]
# <font color='blue'>Заполним пропуски высоты потолков в столбце 'ceiling_height' медианой высоты потолков отфильтрованой по удаленности от центра города .1000/5000/10000/15000/20000+ </font>

# %%
# check
data.ponds_around3000.hist(bins = 150, figsize = (15,3));

# %%
data.cityCenters_nearest.hist(bins = 150, figsize = (15,3));

# %%
height_median1 = data.loc[data['cityCenters_nearest'] <= 1000, 'ceiling_height'].median()
data.loc[data['cityCenters_nearest'] <= 1000, 'ceiling_height'] = data.loc[data['cityCenters_nearest'] <= 1000, 'ceiling_height'].fillna(height_median1)

height_median2 = data.loc[(data['cityCenters_nearest'] <= 5000) & (data['cityCenters_nearest'] > 1000), 'ceiling_height'].median()
data.loc[(data['cityCenters_nearest'] <= 5000) & (data['cityCenters_nearest'] > 1000), 'ceiling_height'] = data.loc[(data['cityCenters_nearest'] <= 5000) & (data['cityCenters_nearest'] > 1000), 'ceiling_height'].fillna(height_median2)

height_median3 = data.loc[(data['cityCenters_nearest'] <= 10000) & (data['cityCenters_nearest'] > 5000), 'ceiling_height'].median()
data.loc[(data['cityCenters_nearest'] <= 10000) & (data['cityCenters_nearest'] > 5000), 'ceiling_height'] = data.loc[(data['cityCenters_nearest'] <= 10000) & (data['cityCenters_nearest'] > 5000), 'ceiling_height'].fillna(height_median3)

height_median4 = data.loc[(data['cityCenters_nearest'] <= 15000) & (data['cityCenters_nearest'] > 10000), 'ceiling_height'].median()
data.loc[(data['cityCenters_nearest'] <= 15000) & (data['cityCenters_nearest'] > 10000), 'ceiling_height'] = data.loc[(data['cityCenters_nearest'] <= 15000) & (data['cityCenters_nearest'] > 10000), 'ceiling_height'].fillna(height_median4)

height_median5 = data.loc[(data['cityCenters_nearest'] <= 20000) & (data['cityCenters_nearest'] > 15000), 'ceiling_height'].median()
data.loc[(data['cityCenters_nearest'] <= 20000) & (data['cityCenters_nearest'] > 15000), 'ceiling_height'] = data.loc[(data['cityCenters_nearest'] <= 20000) & (data['cityCenters_nearest'] > 15000), 'ceiling_height'].fillna(height_median5)

height_median6 = data.loc[data['cityCenters_nearest'] > 20000, 'ceiling_height'].median()
data.loc[data['cityCenters_nearest'] > 20000, 'ceiling_height'] = data.loc[data['cityCenters_nearest'] > 20000, 'ceiling_height'].fillna(height_median6)

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит исключить предупреждения. Иногда их бывает слишком много, поэтому важно уметь их скрывать. В этом тебе поможет библиотека warnings. Попробуй найти подходящий метод и убрать предупреждения.

# %%
# check 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  object
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        21081 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21752 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          23650 non-null  bool
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               23650 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />При заполнении средним или медианой необходимо четко отслеживать изменение других статистик: стандартное отклонение, дисперсию и другие параметры выборки
#
# ... если рассмотреть районность высоты потолков, т.к. в современных районах Питера высота потолков будет ожидаема ниже, чем в исторических, мы увидим, что заполнение подобного объема пропусков медианой или средним значением «размажет» это отличительное свойство объектов недвижимости в центре Питера
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %%
# check
data.ponds_around3000.hist(bins = 150, figsize = (15,3));

# %%
# check
data.days_exposition.hist(bins = 150, figsize = (15,3), range=(0,4));

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Мы с тобой открыли интересную особенность loc — присвоение значений, когда не выбран столбец ...
#
#         height_median = data[data['floors_total'] == height]['ceiling_height'].median()
#         data[data['floors_total'] == height] = data[data['floors_total'] == height].fillna(height_median)
#
# кодом мы заполняем все колонки записей, где выполняется условие
#
#         data[data['floors_total'] == height]
#
# на значение
#
#          data[data['floors_total'] == height].fillna(height_median)
#
# можно посмотреть на df.info() и графики до замены и после ...
#
# т.е. мы заполнили все пропуски, практически во всех колонках датасета
#
# например в колонке о скорости продаж у нас появились квартиры которые продали за 2,7 дня (значение похожее на высоту потолка)
#
# порядок применения loc
#
# https://tonais.ru/library/zamena-odnogo-ili-neskolkih-znacheniy-v-stolbtse-v-dataframe?ysclid=l5jjs9blfj495302948
#
# https://towardsdatascience.com/how-to-use-loc-and-iloc-for-selecting-data-in-pandas-bd09cb4c3d79
#
# Стоит откорректировать код

# %% [markdown]
# <font color='blue'> Не обратил внимание🤦 поправил</font>

# %% [markdown]
# #### Столбцы которые нереально заполнить

# %% [markdown]
# <font color='blue'> По данным столбцам предугадать расстояние не представляется возможным: airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest,ponds_around3000,ponds_nearest </font>

# %% [markdown]
# #### Проверим условие

# %% [markdown]
# <font color='blue'>Проверим данные на предмет выполнения условия общая площадь*0,9  меньше чем жилая + кухня, аномалии удалим</font>

# %%
data = data[~((data['living_area'] + data['kitchen_area']) > (0.9 * data['total_area']))]

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />молодец, что проверяешь корректность значений всех наших площадей после заполнения синтетическими данными,
#
# стоит учесть коэффициент 0,9, т.к. есть (коридоры, сан.узлы, балконы)
#
#         total_area*0.9 <= (living_area + kitchen_area)

# %% [markdown]
# <font color='blue'>Спасибо! Поправил</font>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23188 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23188 non-null  int64
#  1   last_price            23188 non-null  float64
#  2   total_area            23188 non-null  float64
#  3   first_day_exposition  23188 non-null  object
#  4   rooms                 23188 non-null  int64
#  5   ceiling_height        20676 non-null  float64
#  6   floors_total          23104 non-null  float64
#  7   living_area           21290 non-null  float64
#  8   floor                 23188 non-null  int64
#  9   is_apartment          23188 non-null  bool
#  10  studio                23188 non-null  bool
#  11  open_plan             23188 non-null  bool
#  12  kitchen_area          20919 non-null  float64
#  13  balcony               23188 non-null  float64
#  14  locality_name         23188 non-null  object
# ...

# %% [markdown]
# <font color='blue'>Удалим данные где не указана этажность дома, этих данных мало и они не на что не повлияют</font>

# %%
data = data[~data['floors_total'].isnull()]

# %% [markdown]
# <font color='blue'>Методом info() убедимся что пропусков данных больше нет.</font>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23104 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23104 non-null  int64
#  1   last_price            23104 non-null  float64
#  2   total_area            23104 non-null  float64
#  3   first_day_exposition  23104 non-null  object
#  4   rooms                 23104 non-null  int64
#  5   ceiling_height        20601 non-null  float64
#  6   floors_total          23104 non-null  float64
#  7   living_area           21239 non-null  float64
#  8   floor                 23104 non-null  int64
#  9   is_apartment          23104 non-null  bool
#  10  studio                23104 non-null  bool
#  11  open_plan             23104 non-null  bool
#  12  kitchen_area          20882 non-null  float64
#  13  balcony               23104 non-null  float64
#  14  locality_name         23104 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит сменить тип данных в
#
#
#          6   floors_total          23486 non-null  float64

# %% [markdown]
# <font color='blue'>Сделал ниже</font>

# %%
data['floors_total'] = data['floors_total'].astype('int64')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %% [markdown]
# #### Удалим оставшиеся аномалии

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_66ead_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_66ead_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_66ead_row0_col0" class="data row0 col0" >23,104.00</td>
#                         <td id="T_66ead_row0_col1" class="data row0 col1" >23,104.00</td>
# ...

# %% [markdown]
# <div class="alert alert-d
#             anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости в колонках:
#
#         'rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, 4 записи со стоимостью квадратного метра выше 10 млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %% [markdown]
# ##### Удалим аномалии в столбце КОМНАТЫ

# %%
# check
data.rooms.value_counts().to_frame()
# Out:
#     rooms
# 1    7876
# 2    7758
# 3    5639
# 4    1135
# 5     315
# 0     194
# 6      97
# 7      59
# 8      12
# 9       8
# 10      3
# 11      2
# 14      2
# 19      1
# 16      1
# 12      1
# 15      1

# %% [markdown]
# <font color='blue'>Оставим только 0-5 комнат, остальные отбросим из-за незначительного количества</font>

# %%
data = data[data['rooms'] < 6]

# %% [markdown]
# ##### Удалим аномалии в столбце ПЛОЩАДЬ (total_area)

# %%
# check
data.total_area.hist(bins = 150, figsize = (15,3));

# %%
data.boxplot(column='total_area', figsize = (15,15))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры более двухсот квадратных метров можно считать редкостями
#
# особенно это заметно на втором графике, где мы подробно рассматриваем промежуток от 180 кв. метров до 500

# %%
# check
data.total_area.hist(bins = 150, figsize = (15,3), range = (180,500));

# %% [markdown]
# <font color='blue'>При помощи boxplot видно что за усы выходит площадь больше 110м2, по логике удалим значения больше 200</font>

# %%
data = data[data['total_area'] < 200]

# %% [markdown]
# <div class="alert alert-dang
#             er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось выполнить пункт 2.4 из брифа проекта
#
# 2.4.	Найдите и устраните редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.01, .5, .90, .9976])  
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_28323_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_28323_level0_row0" class="row_heading level0 row0" >0.01</th>
#                         <td id="T_28323_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_28323_row0_col1" class="data row0 col1" >25.60</td>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# они помогают увидеть редкости и аномалии в данных

# %% [markdown]
# ##### Удалим аномалии в столбце ВЫСОТА ПОТОЛКОВ (ceiling_height)

# %%
data.boxplot(column='ceiling_height', figsize = (15,15))
# Out:
# <AxesSubplot:>

# %%
data.ceiling_height.hist(bins = 100, figsize = (15,5), range = (1,4));

# %% [markdown]
# <font color='blue'>Высоту потолков меньше 2,5 и больше 3,5 метров предлагаю удалить из-за малого количества данных по ним</font>

# %% [markdown]
# ###### check nan

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22804 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22804 non-null  int64
#  1   last_price            22804 non-null  float64
#  2   total_area            22804 non-null  float64
#  3   first_day_exposition  22804 non-null  object
#  4   rooms                 22804 non-null  int64
#  5   ceiling_height        20303 non-null  float64
#  6   floors_total          22804 non-null  int64
#  7   living_area           20973 non-null  float64
#  8   floor                 22804 non-null  int64
#  9   is_apartment          22804 non-null  bool
#  10  studio                22804 non-null  bool
#  11  open_plan             22804 non-null  bool
#  12  kitchen_area          20619 non-null  float64
#  13  balcony               22804 non-null  float64
#  14  locality_name         22804 non-null  object
# ...

# %%
data = data[((data['ceiling_height'] <= 3.5) & (data['ceiling_height'] >= 2.5)) | data['ceiling_height'].isnull()]

# %%
# check
data.shape[0]
# Out:
# 22499

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         data = data[(data['ceiling_height'] <= 3.5) & (data['ceiling_height'] >= 2.5)]
#
# Так мы познакомились с особенностью фильтрации в библиотеке пандас, все NaN убегают вместе со значениями, которые не подходят под нашу фильтрацию, поэтому процент потери записей огромен
#
# Было 22804 записей, осталось 19998
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками
#
# <b>алгоритм фильтрации столбца с пропусками: задаем основное условие фильтрации, + прибавляем условие не трогать записи с пропусками</b>
#
# стоит обратить внимание на весь код фильтрации, т.к. в нескольких колонках встречаются пропуски

# %% [markdown]
# <font color='blue'>Поправил, так?</font>

# %% [markdown]
# ##### Удалим аномалии в столбце КОЛИЧЕСТВО ДНЕЙ (days_exposition)

# %%
data.boxplot(column='days_exposition', figsize = (15,15))
# Out:
# <AxesSubplot:>

# %%
data.days_exposition.hist(bins = 100, figsize = (15,5), range = (400,800));

# %%
# check
data.shape[0]
# Out:
# 22499

# %%
data = data[(data['days_exposition'] < 550) | (data['days_exposition'].isnull())]

# %%
# check
data.shape[0]
# Out:
# 21122

# %% [markdown]
# <div class="alert alert-dange
#             r">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#        data = data[data['days_exposition'] < 550]
#
#
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками

# %% [markdown]
# <font color='blue'>Поправил</font>

# %% [markdown]
# ##### Удалим аномалии в столбце ЦЕНА ПРОДАЖИ (last_price)

# %%
data.boxplot(column='last_price', figsize = (15,15))
# Out:
# <AxesSubplot:>

# %%
data['last_price'].hist()
# Out:
# <AxesSubplot:>

# %%
data = data[(data['last_price'] > 100_000) & (data['last_price'] < 100_000_000)]

# %% [markdown]
# <font color='blue'>Удалили цену ниже 100.000 и больше 100.000.000</font>

# %% [markdown]
# ##### Удалим аномалии в столбце ПЛОЩАДЬ КУХНИ (kitchen_area)

# %%
data.boxplot(column='kitchen_area', figsize = (15,15))
# Out:
# <AxesSubplot:>

# %%
data.kitchen_area.hist(bins = 100, figsize = (15,5), range = (2,10));

# %%
data.kitchen_area.hist(bins = 100, figsize = (15,5), range = (15,70));

# %% [markdown]
# <font color='blue'>Удалим метраж меньше 5 и больше 30</font>

# %%
# check
data.shape[0]
# Out:
# 21116

# %%
data = data[((data['kitchen_area'] >= 5) & (data['kitchen_area'] <= 30)) | (data['kitchen_area'].isnull())]

# %%
# check
data.shape[0]
# Out:
# 20849

# %% [markdown]
# <div class="alert alert-dang
#             er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#        data = data[(data['kitchen_area'] >= 5) & (data['kitchen_area'] <= 30)]
#
#
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками

# %% [markdown]
# <font color='blue'>Поправил</font>

# %% [markdown]
# ##### Удалим аномалии в столбце ЖИЛАЯ ПЛОЩАДЬ (living_area)

# %%
data.boxplot(column='living_area', figsize = (15,15))
# Out:
# <AxesSubplot:>

# %%
data.living_area.hist(bins = 100, figsize = (15,5), range = (0,15));

# %%
data.living_area.hist(bins = 100, figsize = (15,5), range = (80,140));

# %% [markdown]
# <font color='blue'>Удалим с площадью меньше 14 и больше 95</font>

# %%
# check
data.shape[0]
# Out:
# 20849

# %%
data = data[(data['living_area'] >= 14) & (data['living_area'] <= 95) | (data['living_area'].isnull())]

# %%
# check
data.shape[0]
# Out:
# 20457

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#        data = data[(data['living_area'] >= 14) & (data['living_area'] <= 95)]
#
#
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками

# %% [markdown]
# <font color='blue'>Поправил</font>

# %% [markdown]
# ##### Удалим аномалии в столбце ЭТАЖНОСТЬ ДОМА (floors_total)

# %%
data.boxplot(column='floors_total', figsize = (15,15))
# Out:
# <AxesSubplot:>

# %%
data['floors_total'].value_counts()
# Out:
# 5     4971
# 9     3471
# 12    1243
# 16    1236
# 10    1036
# 25     968
# 4      942
# 17     752
# 6      650
# 3      539
# 14     495
# 7      453
# 18     445
# 24     414
# 15     328
# 23     310
# 2      303
# 8      300
# 19     297
# 22     253
# 20     232
# 13     192
# 11     165
# 27     147
# 21     137
# 26     110
# 35      22
# 28      20
# 1       20
# 36       2
# 34       1
# 60       1
# 29       1
# 33       1
# Name: floors_total, dtype: int64

# %% [markdown]
# <font color='blue'>Удалим дома с этажами 1 и 28+</font>

# %%
data = data[(data['floors_total'] > 1) & (data['floors_total'] <= 27) | (data['floors_total'].isnull())]

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_84057_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_84057_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_84057_row0_col0" class="data row0 col0" >20,389.00</td>
#                         <td id="T_84057_row0_col1" class="data row0 col1" >20,389.00</td>
# ...

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось вернуть часть записей, затем перепроверить

# %% [markdown]
# <font color='blue'>Так? )</font>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> принимается
#
# можно смягчить условия по скорости продаж до 1000 дней, но убрать записи равные 1-у и 2-м дням, почистить минимально аномальную общую площадь до 22-23 квадратов ...

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# <font color='blue'>Добавим стобец цены одного квадратного метра</font>

# %%
data['price_m2'] = data['last_price'] / data['total_area']
data['price_m2'] = data['price_m2'].astype('int64')

# %% [markdown]
# <font color='blue'>Добавим тип этажа квартиры (значения — «первый», «последний», «другой»)</font>

# %%
def floor(num):
    if num['floor'] == num['floors_total'] and num['floor'] != 1:
        return 'последний'
    elif num['floor'] == 1:
        return 'первый'
    return 'другой'
data['floor_type'] = data.apply(floor, axis=1)

# %% [markdown]
# <div class="alert alert-d
#             anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поработать над алгоритмом функции, в результате у нас появилось несколько записей, когда первые этажи попали в категорию последних

# %% [markdown]
# <font color='blue'>Поправил</font>

# %% [markdown]
# <font color='blue'>Переведем расстояние до центра города в километры</font>

# %%
data['cityCenters_nearest'] = round(data['cityCenters_nearest'] / 1000)

# %% [markdown]
# <font color='blue'>Добавим столбцы: день недели публикации объявления (0 — понедельник, 1 — вторник и так далее); месяц публикации объявления; год публикации объявления;</font>

# %%
def day(num):
    if num['day'] == 0:
        return 'понедельник'
    elif num['day'] == 1:
        return 'вторник'
    elif num['day'] == 2:
        return 'среда'
    elif num['day'] == 3:
        return 'четверг'
    elif num['day'] == 4:
        return 'пятница'
    elif num['day'] == 5:
        return 'суббота'
    elif num['day'] == 6:
        return 'воскресенье'

data['day'] = pd.DatetimeIndex(data['first_day_exposition']).dayofweek
data['month'] = pd.DatetimeIndex(data['first_day_exposition']).month
data['year'] = pd.DatetimeIndex(data['first_day_exposition']).year

data['day'] = data.apply(day, axis=1)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Остальные данные добавлены корректно, молодец

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Структура проекта важна и для исполнителя и для заказчика, так они смогут говорить на одном языке и понимать друг-друга
#
# Стоит проверить бриф проекта

# %% [markdown]
# <font color='blue'>Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Самая высокая стоимость за кв.м это в г. Санкт_Петербурге, самая низкая цена в г. Выборг.</font>

# %%
data_pricem2 = data.pivot_table(index='locality_name', values='price_m2', aggfunc=['mean', 'count'])
data_pricem2.columns = ['mean_price_m2', 'count']
data_pricem2['mean_price_m2'] = data_pricem2['mean_price_m2'].astype('int64')
data_pricem2.sort_values('count', ascending=False).head(10)
# Out:
#                    mean_price_m2  count
# locality_name
# Санкт-Петербург           111002  13367
# поселок Мурино             85334    488
# поселок Шушары             77876    404
# Всеволожск                 68384    346
# Колпино                    75356    318
# Пушкин                    102159    317
# поселок Парголово          89442    286
# Гатчина                    69269    270
# деревня Кудрово            92495    261
# Выборг                     58059    206

# %%
data_pricem2.query('count > 100').plot(kind= 'barh', figsize=(19,6), rot = -5, legend = False, fontsize = 16)
# Out:
# <AxesSubplot:ylabel='locality_name'>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Недостаточно найти числа, стоит их показать красиво, удобно и наглядно, чтобы одного взгляда хватило, где самые самые, а где подешевле 📊

# %% [markdown]
# <font color='blue'>Добавил</font>

# %%
data_pricem2.query('count > 100')['mean_price_m2'].plot(kind= 'barh', figsize=(19,6), legend = False, fontsize = 16);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />  молодец
#
#
#     подправил параметры отображения

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#         поселок Парголово	90134.650307	326
#         Гатчина	68624.689769	303
#         деревня Кудрово	92515.993289	298
#         Выборг	58141.489451	237

# %% [markdown]
# <font color='blue'>Поправил.</font>

# %% [markdown]
# #### Выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра.

# %% [markdown]
# <font color='blue'>В столбце 'locality_name' отфильтруем квартиры города Санкт-Петербург и вычислим среднюю цену по каждому километру удаления от центра города. По полученным данным мы видим что чем дальше от центра города тем дешевле стоимость квартиры за м.2.</font>

# %%
data_spb = data.query('locality_name == "Санкт-Петербург"')
data_spb.pivot_table(index='cityCenters_nearest', values='last_price', aggfunc=['mean', 'count']).head(30)
# Out:
#                              mean      count
#                        last_price last_price
# cityCenters_nearest
# 0.0                  1.819000e+07         11
# 1.0                  1.163045e+07        110
# 2.0                  1.151434e+07        185
# 3.0                  9.080285e+06        242
# 4.0                  9.733631e+06        468
# 5.0                  1.062082e+07        630
# 6.0                  1.074818e+07        465
# 7.0                  1.172673e+07        348
# 8.0                  8.281275e+06        491
# 9.0                  6.769634e+06        510
# 10.0                 6.179587e+06        647
# 11.0                 5.921955e+06       1037
# 12.0                 5.730421e+06       1471
# 13.0                 5.986260e+06       1319
# 14.0                 5.493349e+06       1168
# 15.0                 5.631013e+06       1428
# 16.0                 5.306791e+06       1155
# 17.0                 5.141830e+06        780
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Молодец, у тебя получилось сгруппировать и построить таблицу изменения средней цены кв. метра в зависимости от расстояния от центра
#
#
# __Для выполнения 5-го пункта стоит поменять параметр расчета с цены за квадрат на общую стоимость квартиры и построить линейный график__
#
#
#         5.	Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к выбросу на 27-м км.
#
# Можно посмотреть на категории квартир, которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре

# %%
data_spb.query('cityCenters_nearest == 27')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 748             13  14350000.0        74.0  2017-11-28T00:00:00      2
# 5961             6   2250000.0        32.0  2018-02-27T00:00:00      1
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 748             3.13             5         30.0      3         False  ...
# 5961            2.60             2         16.5      2         False  ...
#
#       parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 748                1.0         1496.0               0.0            NaN
# 5961               0.0            NaN               0.0            NaN
#
#      days_exposition  price_m2  floor_type      day  month  year
# 748            128.0    193918      другой  вторник     11  2017
# 5961           178.0     70312   последний  вторник      2  2018
#
# [2 rows x 27 columns]

# %%
data_spb.query('cityCenters_nearest == 27')['last_price'].hist(bins=100, figsize=(10, 10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <font color='blue'>Видим что на 27 километре есть выбросы из трех очень дорогих квартир</font>

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Выше представлена выборка по всем даным
#
# На выборке из Питера на 27-ом км, всего две квартиры, одна из которых - аномалия, которая и приводит к такому выбросу в средней цене
#
#         26.0	4.131000e+06
#         27.0	8.300000e+06
#         28.0	5.026429e+06
#         29.0	4.583333e+06

# %% [markdown]
# <font color='blue'>Увидел, спасибо!</font>

# %% [markdown]
# #### Изучим следующие параметры: - общая площадь; - жилая площадь; - площадь кухни; - цена объекта; - количество комнат; - высота потолков; - этаж квартиры; - тип этажа квартиры («первый», «последний», «другой»); - общее количество этажей в доме; - расстояние до центра города в метрах; - расстояние до ближайшего аэропорта; - расстояние до ближайшего парка;- день и месяц публикации объявления

# %% [markdown]
# <font color='blue'>Изучим следующие параметры:
#   <p>- общая площадь;
#   <p>- жилая площадь;
#   <p>- площадь кухни;
#   <p>- цена объекта;
#   <p>- количество комнат;
#   <p>- высота потолков;
#   <p>- этаж квартиры;
#   <p>- тип этажа квартиры («первый», «последний», «другой»);
#   <p>- общее количество этажей в доме;
#   <p>- расстояние до центра города в метрах;
#   <p>- расстояние до ближайшего аэропорта;
#   <p>- расстояние до ближайшего парка;
#   <p>- день и месяц публикации объявления
#  </font>

# %%
data.hist(bins=100, figsize=(20, 20));

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  20389.000000  2.038900e+04  20389.000000  20389.000000    18070.000000
# mean       9.874933  5.585892e+06     56.085602      1.987248        2.685966
# std        5.628060  4.405228e+06     22.778236      0.929660        0.193183
# min        0.000000  4.300000e+05     13.000000      0.000000        2.500000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.570000
# 50%       10.000000  4.500000e+06     51.000000      2.000000        2.600000
# 75%       14.000000  6.400000e+06     66.700000      3.000000        2.757500
# max       42.000000  9.800000e+07    199.200000      5.000000        3.500000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  20389.000000  18668.000000  20389.000000  18362.000000  20389.000000
# mean      10.808966     31.936727      5.925009      9.804141      0.605326
# ...

# %% [markdown]
# <font color='blue'>Изучим параметр - общая площадь 'total_area'; Квартиры продаются площадью от 13 до 900 м2, средняя площадь 60 м2. По гистограмме я вижу что есть небольшое количество ооочень больших по площади квартир, больше 200м2. Скорее всего эти квартиры будут искажать исследование по зависимостям.</font>

# %% [markdown]
# <font color='blue'>Изучим параметр - жилая площадь 'living_area'; Жилая площадь колеблится от 2 до 409 м2, средняя площадь 31,9 м2. По гистограмме я вижу что есть небольшое количество ооочень больших по площади квартир, больше 180м2. Скорее всего эти квартиры будут искажать исследование по зависимостям. Вижу что минимальное значение жилой площади 2м.кв, такого мне кажется быть не может, скорее всего это выброс который нужо изучить и удалить</font>

# %% [markdown]
# <font color='blue'>Изучим параметр - жилая площадь 'kitchen_area'; Площадь кухни колеблится от 1,3 до 112 м2, средняя площадь 9,8 м2. По гистограмме я вижу что есть небольшое количество ооочень больших по площади кухнь, больше 20м2. Скорее всего эти квартиры будут искажать исследование по зависимостям. Вижу что минимальная площадь кухни 1,3м.кв, такого мне кажется быть не может, скорее всего это выброс который нужо изучить и удалить</font>

# %% [markdown]
# <font color='blue'>Изучим параметр - цена на момент снятия с публикации 'last_price'. Квартиры продаются по цене от 500.000 до 83.820.000. Средняя цена продажи 5.665.000</font>

# %% [markdown]
# <font color='blue'>Изучим параметр - число комнат 'rooms'. Квартиры продаются от 1 до 5 комнат. В среднем и по медиане продаются 2х комнатные квартиры</font>

# %% [markdown]
# <font color='blue'>Изучим параметр - высота потолков 'ceiling_height'. Высота полоков колеблится от 2,5 до 3,5 м. Средняя высота потолков 2,68</font>

# %% [markdown]
# <font color='blue'>Изучим параметр - этаж 'floor'. Квартиры продаются с 1 по 27 этажа, медианное значение 5 этаж  </font>

# %% [markdown]
# <font color='blue'>Изучим параметр - тип этажа квартиры («первый», «последний», «другой») 'floor_type'. Меньше всего продается квартир на первом и последнем этаже. Подавляющее число квартир продаются которые не находятся на первом и последнем этаже.</font>

# %%
data['floor_type'].value_counts()
# Out:
# другой       15123
# последний     2779
# первый        2487
# Name: floor_type, dtype: int64

# %% [markdown]
# <font color='blue'>Изучим параметр - всего этажей в доме 'floors_total'. В нашей базе квартиры находящиеся в домах этажностью от 2 до 27. Медианное значение 9.</font>

# %% [markdown]
# <font color='blue'>Изучим параметр - расстояние до центра города 'cityCenters_nearest'. Квартиры продаются как в центре так и на расстоянии до 65 км от центра. В среднем удаленность составляет 14,74 км.</font>

# %% [markdown]
# <font color='blue'>Изучим параметр - расстояние до ближайшего аэропорта 'airports_nearest'. Удаленность от Аэропорта от 0км до 84км. Средняя удаленность 29км.</font>

# %% [markdown]
# <font color='blue'>Изучим параметр - расстояние до ближайшего парка 'parks_nearest'. Удаленность от парков у основном от 1м до 3100 м, средняя удаленность 489 метров</font>

# %% [markdown]
# <font color='blue'>Изучим параметр - день и месяц публикации объявления 'day', 'month'. Наблюдаем яро выраженное падение продаж в выходные дни субботу и воскресенье. Так же наблюдается сильное снижение продаж в мае, декабре и январе и сезонное снижение в летние месяцы</font>

# %%
data['day'].value_counts()
# Out:
# четверг        3656
# вторник        3610
# пятница        3510
# среда          3380
# понедельник    3079
# суббота        1682
# воскресенье    1472
# Name: day, dtype: int64

# %%
data['month'].value_counts()
# Out:
# 2     2305
# 3     2190
# 11    2087
# 4     2064
# 10    1852
# 9     1717
# 8     1543
# 6     1498
# 7     1432
# 12    1368
# 1     1277
# 5     1056
# Name: month, dtype: int64

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Осталось добавить минивыводов по остальным параметрам
#
# Шаг 4. Проведите исследовательский анализ данных:
# 1.	Изучите следующие параметры объектов:
#     +	общая площадь;
#     +	жилая площадь;
#     +	площадь кухни;
#     +	цена объекта;
#     +	количество комнат;
#     +	высота потолков;
#     +	этаж квартиры;
#     +	тип этажа квартиры («первый», «последний», «другой»);
#     +	общее количество этажей в доме;
#     +	расстояние до центра города в метрах;
#     +	расстояние до ближайшего аэропорта;
#     +	расстояние до ближайшего парка;
#     +	день и месяц публикации объявления.
#
#
# Постройте отдельные гистограммы для каждого из этих параметров. Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.

# %% [markdown]
# # example 1

# %% [markdown]
# #### Изучите, как быстро продавались квартиры

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# стоит выделять разделы проекта заголовками разного уровня, за уровень отвечает количество знаков #
#
#         # example 1
#
#
#         #### example 3

# %% [markdown]
# <font color='blue'>Изучим, как быстро продавались квартиры. Проанализируем столбец 'days_exposition'. Вызвав функцию describe() и hist() мы видим что быстрые продажи это как я теперь понимаю это до 41 дней, а необычно долгие продажи это более 185 дней. Медианный срок продажи занимает 85 дней, средний срок продажи 131 день. Есть два больших выброса на 45 и 60 день .</font>

# %%
data['days_exposition'].describe()
# Out:
# count    17586.000000
# mean       131.204538
# std        126.410384
# min          1.000000
# 25%         41.000000
# 50%         85.000000
# 75%        185.000000
# max        549.000000
# Name: days_exposition, dtype: float64

# %%
data['days_exposition'].hist(bins=100, figsize=(10, 10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит пересчитать статистики скорости продажи после восстановления пропусков

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Можно посмотреть на изменение средней скорости продаж по годам

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Не исследованы моды в 'days_exposition' и как они влияют на скорость продажи, подсказка на что смотреть
#
# [Условия размещения объявлений](https://yandex.ru/support/realty/owner/home/add-ads-housing.html)

# %%
data['days_exposition'].mode()
# Out:
# 0    45.0
# dtype: float64

# %%
data['year'].unique()
# Out:
# array([2019, 2018, 2015, 2017, 2016, 2014])

# %%
data[data['year'] == 2014]['days_exposition'].hist(bins=100, figsize=(10, 10))
# Out:
# <AxesSubplot:>

# %%
data[data['year'] == 2015]['days_exposition'].hist(bins=100, figsize=(10, 10))
# Out:
# <AxesSubplot:>

# %%
data[data['year'] == 2016]['days_exposition'].hist(bins=100, figsize=(10, 10))
# Out:
# <AxesSubplot:>

# %%
data[data['year'] == 2017]['days_exposition'].hist(bins=100, figsize=(10, 10))
# Out:
# <AxesSubplot:>

# %%
data[data['year'] == 2018]['days_exposition'].hist(bins=100, figsize=(10, 10))
# Out:
# <AxesSubplot:>

# %%
data[data['year'] == 2019]['days_exposition'].hist(bins=100, figsize=(10, 10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <font color='blue'>Похоже большинство пропусков в столбце 'days_exposition' пришлось на 2014 год. По графикам видно что с каждым годом популярность сервиса растет что свидетельствует уменьшение сроков продаж квартир</font>

# %% [markdown]
# #### Какие факторы больше всего влияют на общую (полную) стоимость объекта?

# %% [markdown]
# <font color='blue'>Рассмотрим факторы <p>(общей площади;жилой площади;площади кухни;количество комнат;типа этажа (первый, последний, другой);даты размещения (день недели, месяц, год)) <p>И узнаем какие больше всего влияют на общую (полную) стоимость объекта. <p> Как мы видим тип этажа влияет на стоимость, на первом этаже самая дешевая цена, на последнем этаже чуть подороже и самая высокая стоимость квартир между первым и последним этаже</font>

# %%
dats_floor_type = data.pivot_table(index='floor_type', values='last_price', aggfunc=['median', 'count'])
dats_floor_type
# Out:
#                median      count
#            last_price last_price
# floor_type
# другой      4700000.0      15123
# первый      3899000.0       2487
# последний   4190000.0       2779

# %%
dats_floor_type['count'].plot(kind= 'barh', figsize=(19,6), rot = -5, legend = False, fontsize = 16)
# Out:
# <AxesSubplot:ylabel='floor_type'>

# %% [markdown]
# <font color='blue'>Посмотрим статистику по годам, чтобы исключить слишком дорогие и дшевые квартиры возьмем медианное значение, видим что выборка за 2014 год небольшая, ее брать в расчет не будем, цена с 2016 года по 2018 года держалась примерно на одном уровне, с 2019 год цена начинает рости</font>

# %%
data_year = data.pivot_table(index='year', values='last_price', aggfunc=['median', 'count'])
data_year
# Out:
#           median      count
#       last_price last_price
# year
# 2014  14485000.0         15
# 2015   4900000.0        517
# 2016   4400000.0       2049
# 2017   4400000.0       7317
# 2018   4500000.0       7857
# 2019   4998500.0       2634

# %%
data_year['count'].plot(kind= 'barh', figsize=(19,6), rot = -5, legend = False, fontsize = 16)
# Out:
# <AxesSubplot:ylabel='year'>

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Не стоит ориентироваться на 2014 год, __т.к. кол-во объявлений было небольшим,__ а стоимость объявлений высокой, может быть это были маркетинговые объявления в начале работы сервиса или сам рынок только формировался ...
#
# Основная просадка цен происходит с мая и до сентября, у нас период в выборке от ноября 2014 года до 1 мая 2019 года, поэтому 2014 год не показателен из-за малого кол-ва записей, а 2019 из-за фактора сезонности
#
#
# Можно посмотреть на среднюю площадь продаваемых квартир по годам

# %% [markdown]
# <font color='blue'>Посмотрим статистику по месяцам, сильной зависимости на стоимость не обнаружено. Видно что месяц до НГ и месяц после и с мая по август отмечается снижение количества объявлений</font>

# %%
data_month = data.pivot_table(index='month', values='last_price', aggfunc=['median', 'count'])
data_month
# Out:
#           median      count
#       last_price last_price
# month
# 1      4500000.0       1277
# 2      4599000.0       2305
# 3      4572500.0       2190
# 4      4700000.0       2064
# 5      4450000.0       1056
# 6      4300000.0       1498
# 7      4500000.0       1432
# 8      4500000.0       1543
# 9      4600000.0       1717
# 10     4500000.0       1852
# 11     4600000.0       2087
# 12     4550000.0       1368

# %%
data_month['count'].plot(kind= 'barh', figsize=(19,6), rot = -5, legend = False, fontsize = 16)
# Out:
# <AxesSubplot:ylabel='month'>

# %% [markdown]
# <font color='blue'>Посмотрим статистику по дням, меньше всего объявлений выкладывается в воскресенье и субботу. </font>

# %%
data_day = data.pivot_table(index='day', values='last_price', aggfunc=['median', 'count'])
data_day
# Out:
#                 median      count
#             last_price last_price
# day
# воскресенье  4499500.0       1472
# вторник      4620000.0       3610
# понедельник  4590000.0       3079
# пятница      4500000.0       3510
# среда        4550000.0       3380
# суббота      4500000.0       1682
# четверг      4500000.0       3656

# %%
data_day['count'].plot(kind= 'barh', figsize=(19,6), rot = -5, legend = False, fontsize = 16)
# Out:
# <AxesSubplot:ylabel='day'>

# %% [markdown]
# <font color='blue'>Составив корреляцию можно отметить что из исследуемых данных (общей площади;жилой площади;площади кухни;количество комнат) общая площадь больше влияет на цену, чуть меньше жилая площадь, еще меньше площадь кухни и самое низкое влияние оказывает количество комнат.</font>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />за поворот текста отвечает параметр rot

# %%
data_dep = data[['total_area', 'living_area', 'kitchen_area', 'rooms','floor_type', 'day', 'last_price']]
data_dep.corr()
# Out:
#               total_area  living_area  kitchen_area     rooms  last_price
# total_area      1.000000     0.924088      0.548836  0.778295    0.717193
# living_area     0.924088     1.000000      0.295703  0.882712    0.607527
# kitchen_area    0.548836     0.295703      1.000000  0.140662    0.530196
# rooms           0.778295     0.882712      0.140662  1.000000    0.406823
# last_price      0.717193     0.607527      0.530196  0.406823    1.000000

# %%
pd.plotting.scatter_matrix(data_dep, figsize=(15, 15));

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Стоит отдельно построить графики в самом важном разделе исследования
#
# Шаг 4. Проведите исследовательский анализ данных:
#
# 3.	Какие факторы больше всего влияют на общую (полную) стоимость объекта?
#     Изучите, зависит ли цена от:
#     +	общей площади;
#     +	жилой площади;
#     +	площади кухни;
#     +	количества комнат;
#     +	этажа, на котором расположена квартира (первый, последний, другой);
#     +	даты размещения (день недели, месяц, год).
#
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
#
#
#
# __Советы по графикам:__
#
# + зависимость параметров (от площади, числа комнат, удалённости от центра) оптимальнее рассматривать на точечных графиках (тип scatter),
# + динамику на линейных (это про сравнение цен за год, месяц, день недели), — стоит сгруппировать значения и рассчитать среднее или медианное значение
# + сравнение цен на барах (для сравнение средней стоимости квартиры по трем категориям), — стоит сгруппировать значения и рассчитать среднее или медианное значение

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# <font color='blue'>Проведя исследовательский анализ можно сделать вывод что самое большое влияние на стоимость квартиры оказывает площадь квартиры, удаленность от центра города, тип этажа и город. Меньше всего влияние на цену оказывает количество комнат, площадь кухни и дата публкации. Медианная стоимость лучше отражает среднюю стоимость квартиры, это 4.500.000. Средняя площаь квартиры очень близка к медианно и составляет 56 и 51м2 соответственно. Среднее количество комнат 2. Медианное значение потолков 2,6. В среднем продаются квартиры на 4-6 этажах. Средняя удаленность от центра 13-14,6км. Средняя цена за м2 это 96545 руб/м2.</font>

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  20389.000000  2.038900e+04  20389.000000  20389.000000    18070.000000
# mean       9.874933  5.585892e+06     56.085602      1.987248        2.685966
# std        5.628060  4.405228e+06     22.778236      0.929660        0.193183
# min        0.000000  4.300000e+05     13.000000      0.000000        2.500000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.570000
# 50%       10.000000  4.500000e+06     51.000000      2.000000        2.600000
# 75%       14.000000  6.400000e+06     66.700000      3.000000        2.757500
# max       42.000000  9.800000e+07    199.200000      5.000000        3.500000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  20389.000000  18668.000000  20389.000000  18362.000000  20389.000000
# mean      10.808966     31.936727      5.925009      9.804141      0.605326
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Направление правильное, можно использовать мой пример из блока фильтрации - заказчика проекта маловероятно заинтересуют такое кол-во цифр и чисел с непонятными разрядами и названиями ... - выделяем  только самые интересные параметры

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть  инсайты, анализ рынка недвижимости, молодец
#
# Можно добавить значения исследуемых параметров (средние или медианные)
#
# Осталось перепроверить итоговый вывод после исправления всех комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнил исследовательскую работу, молодец, показал хороший уровень навыков программирования
#
# Критические ❌ комментарии
#
# + проверить корректность заполнения таблицы
# + сменить тип данных
# + настроить фильтрацию редких значений в п. 2.4
# + подправить функцию категоризации этажности
# + добавить выводов в п.4.1
# + пересчитать скорость продаж
# + подправить графики в п. 4.3
# + дополнить итоговый вывод цифрами и сравнениями
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)

# %% [markdown]
# ### Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
# check
import seaborn as sns

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']])
plt.gcf().set_size_inches(12,12);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
